# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/Windows/Desktop/projects/House Price India.csv")

# %%
df.head()
# Out:
#            id   Date  No of bedrooms  No of bathrooms  living area  lot area  \
# 0  6762810635  42491               4             2.50         2920      4000
# 1  6762810998  42491               5             2.75         2910      9480
# 2  6762812605  42491               4             2.50         3310     42998
# 3  6762812919  42491               3             2.00         2710      4500
# 4  6762813105  42491               3             2.50         2600      4750
#
#    No of floors  waterfront present  No of views  house condition  ...  \
# 0           1.5                   0            0                5  ...
# 1           1.5                   0            0                3  ...
# 2           2.0                   0            0                3  ...
# 3           1.5                   0            0                4  ...
# 4           1.0                   0            0                4  ...
#
#    Built Year  Renovation Year  Postal Code  Lattitude  Longitude  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'Date', 'No of bedrooms', 'No of bathrooms', 'living area',
#        'lot area', 'No of floors', 'waterfront present', 'No of views',
#        'house condition', 'house grade', 'house area(excluding basement)',
#        'Area of the basement', 'Built Year', 'Renovation Year', 'Postal Code',
#        'Lattitude', 'Longitude', 'living_area_renov', 'lot_area_renov',
#        'No of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
df.shape
# Out:
# (14619, 23)

# %%
df.isnull().sum()
# Out:
# id                                0
# Date                              0
# No of bedrooms                    0
# No of bathrooms                   0
# living area                       0
# lot area                          0
# No of floors                      0
# waterfront present                0
# No of views                       0
# house condition                   0
# house grade                       0
# house area(excluding basement)    0
# Area of the basement              0
# Built Year                        0
# Renovation Year                   0
# Postal Code                       0
# Lattitude                         0
# Longitude                         0
# living_area_renov                 0
# lot_area_renov                    0
# No of schools nearby              0
# Distance from the airport         0
# Price                             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14619 entries, 0 to 14618
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14619 non-null  int64
#  1   Date                            14619 non-null  int64
#  2   No of bedrooms                  14619 non-null  int64
#  3   No of bathrooms                 14619 non-null  float64
#  4   living area                     14619 non-null  int64
#  5   lot area                        14619 non-null  int64
#  6   No of floors                    14619 non-null  float64
#  7   waterfront present              14619 non-null  int64
#  8   No of views                     14619 non-null  int64
#  9   house condition                 14619 non-null  int64
#  10  house grade                     14619 non-null  int64
#  11  house area(excluding basement)  14619 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id          Date  No of bedrooms  No of bathrooms  \
# count  1.461900e+04  14619.000000    14619.000000     14619.000000
# mean   6.762821e+09  42604.546412        3.379233         2.129557
# std    6.237162e+03     67.343747        0.938655         0.769955
# min    6.762810e+09  42491.000000        1.000000         0.500000
# 25%    6.762815e+09  42546.000000        3.000000         1.750000
# 50%    6.762821e+09  42600.000000        3.000000         2.250000
# 75%    6.762826e+09  42662.000000        4.000000         2.500000
# max    6.762832e+09  42734.000000       33.000000         8.000000
#
#         living area      lot area  No of floors  waterfront present  \
# count  14619.000000  1.461900e+04  14619.000000        14619.000000
# mean    2098.156851  1.509369e+04      1.502326            0.007661
# std      928.218740  3.792089e+04      0.540241            0.087196
# min      370.000000  5.200000e+02      1.000000            0.000000
# ...

# %%
##EDA
#corr
cor=df.corr()
cor
# Out:
#                                       id      Date  No of bedrooms  \
# id                              1.000000  0.045778       -0.328899
# Date                            0.045778  1.000000       -0.015467
# No of bedrooms                 -0.328899 -0.015467        1.000000
# No of bathrooms                -0.516909 -0.026433        0.509783
# living area                    -0.648058 -0.021770        0.570441
# lot area                       -0.100298  0.004374        0.034438
# No of floors                   -0.312237 -0.010230        0.177208
# waterfront present             -0.112959  0.011997       -0.006247
# No of views                    -0.292699 -0.004219        0.078157
# house condition                -0.044797 -0.027138        0.026326
# house grade                    -0.673374 -0.032878        0.352795
# house area(excluding basement) -0.565021 -0.015781        0.473482
# Area of the basement           -0.290839 -0.015717        0.300367
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(cor)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['id', 'Date', 'No of bedrooms', 'No of bathrooms', 'living area',
#        'lot area', 'No of floors', 'waterfront present', 'No of views',
#        'house condition', 'house grade', 'house area(excluding basement)',
#        'Area of the basement', 'Built Year', 'Renovation Year', 'Postal Code',
#        'Lattitude', 'Longitude', 'living_area_renov', 'lot_area_renov',
#        'No of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
X=df[['No of bedrooms', 'No of bathrooms', 'living area',
       'lot area', 'No of floors', 'waterfront present', 'No of views',
       'house condition', 'house grade',
       'Area of the basement']]
y=df['Price']

# %%
X.head()
# Out:
#    No of bedrooms  No of bathrooms  living area  lot area  No of floors  \
# 0               4             2.50         2920      4000           1.5
# 1               5             2.75         2910      9480           1.5
# 2               4             2.50         3310     42998           2.0
# 3               3             2.00         2710      4500           1.5
# 4               3             2.50         2600      4750           1.0
#
#    waterfront present  No of views  house condition  house grade  \
# 0                   0            0                5            8
# 1                   0            0                3            8
# 2                   0            0                3            9
# 3                   0            0                4            8
# 4                   0            0                4            9
#
#    Area of the basement
# 0                  1010
# 1                     0
# 2                     0
# 3                   830
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
##model training
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(regression.coef_)
# Out:
# [-2.88080729e+04 -1.43491367e+04  1.80054680e+02 -4.21489219e-01
#  -1.19588100e+03  5.75493629e+05  5.72766724e+04  5.98576492e+04
#   1.05336395e+05  2.36882735e+01]

# %%
reg_pred=regression.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,reg_pred)
# Out:
# 0.6210146088072979

# %%
##pickling 
import pickle

# %%
pickle.dump(regression,open('regmodel.pkl','wb'))
